# %% [markdown]
# <div style="
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#     background: linear-gradient(to right, #E23744, #C81D30);
#     height: 100px;
#     border-radius: 8px;
#     text-align: center;">
#
# <h1 style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-weight: bold;
#         font-size: 50px;
#         margin: 0 0 20px 0;">
#         Zomato Food Delivery Performance Analysis
# </h1>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;
#     font-family: 'Times New Roman', Times, serif;
#     color: black;">
#
# <div style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     text-align: justify;
#     line-height: 1.6;">
#
# <b>Dataset Overview </b> - This dataset contains information related to food delivery operations, including details about delivery persons, orders, restaurants, delivery conditions, and delivery performance. It provides information on factors such as delivery person age and rating, order placement and pickup times, weather conditions, road traffic density, vehicle condition, type of order, type of vehicle, festival periods, city type, delivery distance, and delivery time.
# <br>
# <b> Submitted by</b> - Jyothi KV
# <br>
# <b> Number of Records and Variables </b> - 38,964 x 26
# <br/>
# <b> Nature of Variables </b> - Numerical, categorical and datetime features
# </br>
# <b> Dataset Url </b> - https://huggingface.co/datasets/allenborochin/zomato_delivery_EDA/tree/main
#
# </div>
# </div>

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#     Introduction
# </h2>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     In India, home delivery services have become a common part of everyday life, especially in major cities. With increasingly busy lifestyles, people value convenience and quick delivery, making food delivery applications an important part of the modern food-service industry. Among the major food delivery platforms in India, Zomato has a significant presence across the country.
#
# </p>
# </div>

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#     Problem Definition
# </h2>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     Food delivery services depend on timely and efficient deliveries to maintain customer satisfaction. However, delivery times can vary due to several operational and environmental factors, including travel distance, weather conditions, traffic density, vehicle type, and order-related characteristics. Identifying which factors have the greatest influence on delivery performance is essential for improving service efficiency and reducing delivery delays. This project addresses the problem of understanding the key factors associated with variations in Zomato's food delivery time using data-driven analysis.
# </p>

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#     Aim
# </h2>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     This capstone project aims to analyse Zomato's food delivery performance in India and identify the key factors that influence the time taken to deliver an order.

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#     Objectives
# </h2>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;
#     font-family: 'Times New Roman', Times, serif;
#     color: black;">
#
# <h2 style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 26px;
#     font-weight: bold;
#     margin: 0 0 15px 0;">
#     Exploratory Data Analysis
# </h2>
#
# <div style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;">
#
# 1. Calculate the average delivery rating.<br>
# 2. Calculate the average age of delivery partners.<br>
# 3. Create an <b>Order Pickup Time</b> feature by calculating the time taken between order placement and order pickup.<br>
# 4. Categorize order placement time into <b>Morning, Afternoon, Evening, and Night</b> by creating a new <b>Order Period</b> column.<br>
# 5. Analyze the distribution of orders across the different time-of-day categories.<br>
# 6. Analyze the relationship between delivery person age and delivery speed category.<br>
# 7. Examine the effect of weather conditions on delivery time.<br>
# 8. Study the combined influence of traffic density and weather conditions on delivery time.<br>
# 9. Analyze the impact of traffic conditions and festival periods on delivery time.<br>
# 10. Compare delivery speed categories across different city types.<br>
# 11. Investigate the relationship between vehicle condition and delivery distance.<br>
# 12. Analyze the association between vehicle type and delivery distance.<br>
# 13. Examine how order pickup time varies across different delivery speed categories.<br>
# 14. Analyze the impact of festivals on order pickup time.<br>
# 15. Compare delivery time across different vehicle types.<br>
# 16. Examine how multiple deliveries influence delivery speed categories.<br>
# 17. Compare order pickup time across different city types.<br>
# 18. Analyze the relationship between delivery speed categories and customer ratings.<br>
# 19. Examine how order type and city type influence delivery time.
#
# </div>
# </div>

# %% [markdown]
# <div style="
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#     background: linear-gradient(to right, #E23744, #C81D30);
#     min-height: 90px;
#     border-radius: 8px;
#     text-align: center;">
#
# <h2 style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-weight: bold;
#         font-size: 30px;
#         margin: 0 0 8px 0;">
#         Phase 1
# </h2>
#
# <p style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-size: 22px;
#         margin: 0;">
#         Importing Libraries, Data Loading and Data Understanding
# </p>
#
# </div>

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#    Importing Libraries
# </h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import plotly.express as px

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#     Data Loading
# </h2>

# %%
df = pd.read_csv("zomato.csv")
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 38959  0x1178   RANCHIRES16DEL01                 35.0
# 38960  0x7c09      JAPRES04DEL01                 30.0
# 38961  0x4f8d     CHENRES08DEL03                 30.0
# 38962  0x5eee    COIMBRES11DEL01                 20.0
# 38963  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.2            30.327968             78.046106
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# ...

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#     Data Understanding
# </h2>

# %%
df.shape
# Out:
# (38964, 22)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38964 entries, 0 to 38963
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           38964 non-null  str
#  1   Delivery_person_ID           38964 non-null  str
#  2   Delivery_person_Age          37945 non-null  float64
#  3   Delivery_person_Ratings      37909 non-null  float64
#  4   Restaurant_latitude          38964 non-null  float64
#  5   Restaurant_longitude         38964 non-null  float64
#  6   Delivery_location_latitude   38964 non-null  float64
#  7   Delivery_location_longitude  38964 non-null  float64
#  8   Order_Date                   38964 non-null  str
#  9   Time_Orderd                  38129 non-null  str
#  10  Time_Order_picked            38964 non-null  str
#  11  Weather_conditions           38964 non-null  str
#  12  Road_traffic_density         38964 non-null  str
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)',
#        'distance_km', 'delivery_speed'],
#       dtype='str')

# %% [markdown]
# <h3 style="
#     text-align: Left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Column Description
# </h3>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;
#     font-family: 'Times New Roman', Times, serif;
#     color: black;">
#
# <table style="
#     width: 100%;
#     border-collapse: collapse;
#     background-color: #FFF1F2;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     color: black;">
#
# <tr style="background-color: #E23744; color: white;">
#     <th style="border: 1px solid #E23744; padding: 10px; text-align: left;">
#         Column Name
#     </th>
#     <th style="border: 1px solid #E23744; padding: 10px; text-align: left;">
#         Short Description
#     </th>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>ID</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Unique identification number for each order.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Delivery_person_ID</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Unique ID of the delivery person.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Delivery_person_Age</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Age of the delivery person.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Delivery_person_Ratings</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Customer rating received by the delivery person.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Restaurant_latitude</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Latitude of the restaurant location.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Restaurant_longitude</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Longitude of the restaurant location.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Delivery_location_latitude</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Latitude of the delivery location.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Delivery_location_longitude</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Longitude of the delivery location.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Order_Date</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Date on which the order was placed.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Time_Orderd</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Time at which the order was placed.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Time_Order_picked</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Time at which the order was picked up.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Weather_conditions</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Weather condition during delivery.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Road_traffic_density</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Traffic level during delivery.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Vehicle_condition</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Condition of the delivery vehicle.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Type_of_order</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Type of food order.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Type_of_vehicle</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Vehicle used for delivery.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>multiple_deliveries</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Number of orders handled in the same delivery trip.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Festival</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Indicates whether the delivery occurred during a festival.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>City</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Classification of the city where the delivery occurred.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>Time_taken (min)</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Total delivery time in minutes.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>distance_km</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Distance between restaurant and delivery location in kilometres.</td>
# </tr>
#
# <tr>
#     <td style="border: 1px solid #E23744; padding: 10px;"><b>delivery_speed</b></td>
#     <td style="border: 1px solid #E23744; padding: 10px;">Category indicating the delivery speed.</td>
# </tr>
#
# </table>
# </div>

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# ...

# %%
df.tail()
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 38959  0x1178   RANCHIRES16DEL01                 35.0
# 38960  0x7c09      JAPRES04DEL01                 30.0
# 38961  0x4f8d     CHENRES08DEL03                 30.0
# 38962  0x5eee    COIMBRES11DEL01                 20.0
# 38963  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 38959                      4.2            23.371292             85.327872
# 38960                      4.8            26.902328             75.794257
# 38961                      4.9            13.022394             80.242439
# 38962                      4.7            11.001753             76.986241
# 38963                      4.9            23.351058             85.325731
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 38959                   23.481292                    85.437872  08-03-2022
# ...

# %%
df.sample()
# Out:
#           ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 8284  0x7189     PUNERES18DEL03                 24.0                      4.8
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 8284            18.593481             73.785901                   18.653481
#
#       Delivery_location_longitude  Order_Date  Time_Orderd  ...  \
# 8284                    73.845901  01-04-2022  0.791666667  ...
#
#      Road_traffic_density Vehicle_condition Type_of_order  Type_of_vehicle  \
# 8284               Medium                 0          Meal       motorcycle
#
#      multiple_deliveries Festival           City Time_taken (min) distance_km  \
# 8284                 0.0       No  Metropolitian               16    9.191497
#
#       delivery_speed
# 8284            Fast
#
# [1 rows x 22 columns]

# %%
df.dtypes
# Out:
# ID                                 str
# Delivery_person_ID                 str
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                         str
# Time_Orderd                        str
# Time_Order_picked                  str
# Weather_conditions                 str
# Road_traffic_density               str
# Vehicle_condition                int64
# Type_of_order                      str
# Type_of_vehicle                    str
# multiple_deliveries            float64
# Festival                           str
# City                               str
# Time_taken (min)                 int64
# distance_km                    float64
# delivery_speed                     str
# dtype: object

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         37945.000000             37909.000000         38964.000000
# mean             29.607089                 4.631879            18.915583
# std               5.763202                 0.317006             5.460635
# min              20.000000                 2.500000             9.957144
# 25%              25.000000                 4.500000            12.986047
# 50%              30.000000                 4.700000            19.065838
# 75%              35.000000                 4.900000            22.751234
# max              39.000000                 5.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          38964.000000                38964.000000
# mean              76.914536                   18.979545
# std                3.498179                    5.462504
# min               72.768726                    9.967144
# ...

# %% [markdown]
# <div style="
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#     background: linear-gradient(to right, #E23744, #C81D30);
#     min-height: 120px;
#     border-radius: 8px;
#     text-align: center;
#     padding: 15px 25px;">
#
# <h2 style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-weight: bold;
#         font-size: 30px;
#         margin: 0 0 8px 0;">
#         Phase 2
#     </h2>
#
# <p style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-size: 22px;
#         text-align: center;
#         max-width: 1000px;
#         margin: 0;">
#         Data Cleaning and Preprocessing: Handling null values, correcting inconsistencies and data types, removing duplicates, feature engineering and detecting outliers
#     </p>
#
# </div>

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#     Data Cleaning and Preprocessing
# </h2>

# %% [markdown]
# <h3 style="
#     text-align: Left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Handling Null Values
# </h3>

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1019
# Delivery_person_Ratings        1055
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                     835
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken (min)                  0
# distance_km                       0
# delivery_speed                    0
# dtype: int64

# %%
#handling null values-->Delivery_person_Age,Delivery_person_Ratings,Time_Orderd
df['Delivery_person_Age'].unique()
# Out:
# array([36., 21., 23., 34., 24., 29., 35., 33., 25., 31., 37., 27., 32.,
#        26., 38., 20., 22., nan, 28., 39., 30.])

# %%
df['Delivery_person_Age']= df['Delivery_person_Age'].fillna(df['Delivery_person_Age'].mean())
df['Delivery_person_Age'].unique()
# Out:
# array([36.        , 21.        , 23.        , 34.        , 24.        ,
#        29.        , 35.        , 33.        , 25.        , 31.        ,
#        37.        , 27.        , 32.        , 26.        , 38.        ,
#        20.        , 22.        , 29.60708921, 28.        , 39.        ,
#        30.        ])

# %%
df['Delivery_person_Ratings'].unique()
# Out:
# array([4.2, 4.7, 4.3, 4.5, 4. , 4.1, 5. , 4.8, 4.9, 4.6, nan, 4.4, 3.8,
#        3.9, 3.7, 2.6, 3.5, 2.5, 3.6, 3.1, 2.7, 3.3, 3.4, 3.2, 2.8, 2.9,
#        3. ])

# %%
df['Delivery_person_Ratings'] =df['Delivery_person_Ratings'].fillna(df['Delivery_person_Ratings'].mean())
df['Delivery_person_Ratings'].unique()
# Out:
# array([4.2       , 4.7       , 4.3       , 4.5       , 4.        ,
#        4.1       , 5.        , 4.8       , 4.9       , 4.6       ,
#        4.63187897, 4.4       , 3.8       , 3.9       , 3.7       ,
#        2.6       , 3.5       , 2.5       , 3.6       , 3.1       ,
#        2.7       , 3.3       , 3.4       , 3.2       , 2.8       ,
#        2.9       , 3.        ])

# %%
print("Time_Orderd missing:", df['Time_Orderd'].isna().sum())
print(df['Time_Orderd'].dtype)
# Out:
# Time_Orderd missing: 835
# str

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     Missing values in <b>Time_Orderd</b> were retained as <b>missing</b> because replacing them with the mode would introduce an artificial order time and could distort the derived Order_to_Pickup_Time feature. Consequently, pickup time could not be calculated for those records and was retained as missing.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Correcting Inconsistencies and Datatypes
# </h3>

# %%
df['Delivery_person_Age'] = df['Delivery_person_Age'].astype(int)
df['Delivery_person_Age'].dtypes
# Out:
# dtype('int64')

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'],dayfirst=True)
print(df['Order_Date'].dtypes)
# Out:
# datetime64[us]

# %%
df['Time_Orderd'] = pd.to_datetime(
    df['Time_Orderd'],
    format='%H:%M',
    errors='coerce'
)


df['Time_Order_picked'] = pd.to_datetime(
    df['Time_Order_picked'],
    format='%H:%M',
    errors='coerce'
)
print(df['Time_Orderd'].dtypes)
print(df['Time_Order_picked'].dtypes)
# Out:
# datetime64[us]
# datetime64[us]

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Removing Duplicates
# </h3>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     There is no duplicates in this dataset.

# %% [markdown]
# <h3 style="
#     text-align: left ;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Feature Engineering
# </h3>

# %%
Vehicle_condition_converted= []

for i in df['Vehicle_condition']:
    if i == 0:
        Vehicle_condition_converted.append('Poor condition')
    elif i == 1:
        Vehicle_condition_converted.append('Average condition')
    else:
        Vehicle_condition_converted.append('Good condition')

df['Vehicle_condition_converted']=Vehicle_condition_converted
print(df['Vehicle_condition_converted'])
# Out:
# 0           Good condition
# 1        Average condition
# 2        Average condition
# 3           Poor condition
# 4        Average condition
#                ...
# 38959       Good condition
# 38960    Average condition
# 38961    Average condition
# 38962       Poor condition
# 38963       Good condition
# Name: Vehicle_condition_converted, Length: 38964, dtype: str

# %%
order_minutes = (
    df['Time_Orderd'].dt.hour * 60
    + df['Time_Orderd'].dt.minute
)

pickup_minutes = (
    df['Time_Order_picked'].dt.hour * 60
    + df['Time_Order_picked'].dt.minute
)

df['Order_to_Pickup_Time'] = pickup_minutes - order_minutes

# Correct for crossing midnight
df.loc[
    df['Order_to_Pickup_Time'] < 0,
    'Order_to_Pickup_Time'
] += 1440

# %%
df['Order_to_Pickup_Time'].unique()
# Out:
# array([15., 10.,  5., nan])

# %%
df['order_hour']= df['Time_Orderd'].dt.hour
df[['order_hour','Time_Orderd']]
# Out:
#        order_hour         Time_Orderd
# 0            21.0 1900-01-01 21:55:00
# 1            14.0 1900-01-01 14:55:00
# 2            17.0 1900-01-01 17:30:00
# 3             9.0 1900-01-01 09:20:00
# 4            19.0 1900-01-01 19:50:00
# ...           ...                 ...
# 38959        21.0 1900-01-01 21:45:00
# 38960        11.0 1900-01-01 11:35:00
# 38961        23.0 1900-01-01 23:50:00
# 38962        13.0 1900-01-01 13:35:00
# 38963        17.0 1900-01-01 17:10:00
#
# [38964 rows x 2 columns]

# %%
order_period= []
for i in df['order_hour']:
    if i >= 5.0 and i< 12.0:
        order_period.append('Morning')
    elif i >=12.0 and i <16.0:
        order_period.append('Noon/Afternoon')
    elif i >=16.0 and i <20.0:
        order_period.append('Evening')
    else:
        order_period.append('Night')
df['order_period']= order_period

df['order_period']
# Out:
# 0                 Night
# 1        Noon/Afternoon
# 2               Evening
# 3               Morning
# 4               Evening
#               ...
# 38959             Night
# 38960           Morning
# 38961             Night
# 38962    Noon/Afternoon
# 38963           Evening
# Name: order_period, Length: 38964, dtype: str

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)',
#        'distance_km', 'delivery_speed', 'Vehicle_condition_converted',
#        'Order_to_Pickup_Time', 'order_hour', 'order_period'],
#       dtype='str')

# %% [markdown]
# <h3 style="
#     text-align: left ;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Detecting Outliers
# </h3>

# %%
Q1 = df.Order_to_Pickup_Time.quantile(0.25)
Q3 = df.Order_to_Pickup_Time.quantile(0.75)
Q1, Q3
# Out:
# (np.float64(5.0), np.float64(15.0))

# %%
IQR =Q3-Q1
IQR
# Out:
# np.float64(10.0)

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (np.float64(-10.0), np.float64(30.0))

# %%
df[(df.Order_to_Pickup_Time<lower_limit)|(df.Order_to_Pickup_Time>upper_limit)]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min), distance_km, delivery_speed, Vehicle_condition_converted, Order_to_Pickup_Time, order_hour, order_period]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     No Outliers were found.

# %% [markdown]
# <div style="
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#     background: linear-gradient(to right, #E23744, #C81D30);
#     min-height: 120px;
#     border-radius: 8px;
#     text-align: center;
#     padding: 15px 25px;">
#
# <h2 style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-weight: bold;
#         font-size: 30px;
#         margin: 0 0 8px 0;">
#         Phase 3
#     </h2>
#
# <p style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-size: 22px;
#         text-align: center;
#         max-width: 1000px;
#         margin: 0;">
#         Data Analysis and Visualizations: EDA with visualizations and EDA without visualizations
#     </p>
#
# </div>

# %% [markdown]
# <h3 style="
#     text-align: center ;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size:30px;
#     padding: 20px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Univariate Analysis
# </h3>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     1) What is the average delivery rating of delivery partners?
# </h3>

# %%
print(df['Delivery_person_Ratings'].mean().round(1))
# Out:
# 4.6

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b>The average delivery rating of Zomato delivery partners is <b>4.6</b>. <br>
#     <b> Insight :</b>This indicates a high level of customer satisfaction with the delivery service provided by the delivery partners. </br>
# </p>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#    2) What is the average age of delivery partners?
# </h3>

# %%
print(df['Delivery_person_Age'].mean().round())
# Out:
# 30.0

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The average age of Zomato delivery partners is <b>30 years</b>.<br>
#     <b> Insight :</b>This indicates that most delivery partners belong to a relatively young workforce.</br>
# </p>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     3) How much time, on average, does it take for an order to be picked up after it is placed?
# </h3>

# %%
print(df['Order_to_Pickup_Time'].mean().round())
# Out:
# 10.0

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The average time taken to pick up the order is <b>10 minutes</b>. <br>
#     <b> Insight :</b>This indicates that, on average, orders are picked up within 10 minutes of being placed, suggesting a relatively short waiting time before the delivery process begins.</br>
# </p>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     4) How are orders distributed across different order periods (Morning, Afternoon, Evening, and Night)?
# </h3>

# %%
print(df['order_period'].value_counts())
# Out:
# order_period
# Night             18754
# Evening           11546
# Morning            6125
# Noon/Afternoon     2539
# Name: count, dtype: int64

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation : Night</b> has the highest number of orders, with <B>18,754</B> orders.<B>Evening</B> is the second-highest period, with <B>11,546 </B>orders.
# <B>Morning</B> has <B>6,125</B> orders.<B>Noon/Afternoon</B> has the lowest number of orders, with only <B>2,539</B> orders.Overall, the data shows that orders are concentrated more heavily during the evening and night.
#     <br>
#     <b> Insight :</b> Night and evening represent the peak ordering periods, indicating higher customer demand during these hours. This suggests that Zomato may need increased delivery-partner availability and efficient order allocation during evening and night hours to handle peak demand and maintain delivery performance.
#     </br>
# </p>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     5) What is the distribution of delivery distances across all orders?
# </h3>

# %%
sns.histplot(data=df,x='distance_km',bins=20,color='red',edgecolor='none')
plt.xlabel('Delivery Distance (km)')
plt.ylabel('Number of Orders')
plt.title('Distribution of Delivery Distance')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The delivery distance shows a multi-peaked distribution, with order volumes concentrated around certain distance ranges rather than smoothly tapering off as distance increases. Higher order volumes are seen around <b>2.5 km, 5.5 km, 8 km, 11 km, and 14 km</b>. There is also a noticeable gap between <b>14.5 km and 16 km</b>, followed by another increase in orders from <b>16.5 km to 21 km.</b>
# <br>
#     <b> Insight :</b>The orders are not evenly spread across all delivery distances. Most orders are concentrated at certain distance ranges, which may be because the service covers certain areas more frequently than others.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     6) What is the distribution of orders across different city types?
# </h3>

# %%
colors = ['red', 'skyblue', 'green']
city_counts= df['City'].value_counts()
plt.pie(
    city_counts.values,
    labels=city_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=colors
)

plt.title('Distribution of Orders Across City Types')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The pie chart shows that <b>Metropolitan</b> areas account for the largest share of orders at <b>77.1%</b>, followed by <b>Urban</b> areas at <b>22.5%. Semi-Urban</b> areas contribute only <b>0.4%</b> of the total orders. Together, Metropolitan and Urban areas account for <b>99.6% </b>of all orders.
# <br>
#     <b> Insight :</b> The order distribution is heavily concentrated in Metropolitan and Urban areas, while Semi-Urban areas represent only a very small proportion of total orders. This indicates that the dataset is predominantly driven by orders from urban markets. The low order volume in Semi-Urban areas, along with their previously observed higher delivery times, suggests that delivery performance differs across city types.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     7) Which restaurant locations receive the highest number of orders?
# </h3>

# %%
restaurant_orders = (
    df.groupby(['Restaurant_latitude', 'Restaurant_longitude'])
      .size()
      .reset_index(name='Order_Count'))

px.scatter_map(
    restaurant_orders,
    lat='Restaurant_latitude',
    lon='Restaurant_longitude',
    size='Order_Count',
    color='Order_Count',
    zoom=5,
    map_style='open-street-map',
    title='Restaurant Locations by Order Volume')

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The geographic scatter map shows that restaurant order volumes vary across different locations in India. Higher order volumes are concentrated in several major urban and regional centres, while some locations have comparatively lower order volumes. Overall, the orders are geographically distributed across multiple parts of India, with noticeable differences in order intensity between locations.
# <br>
#     <b> Insight :</b> The variation in order volume indicates that customer demand is not evenly distributed across restaurant locations. Locations with higher order volumes represent areas of stronger observed demand in this dataset, while lower-volume locations may require further analysis to understand the reasons behind the difference.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     8)Which delivery areas receive the highest number of orders?
# </h3>

# %%
delivery_areas = (
    df.groupby(['Delivery_location_latitude', 'Delivery_location_longitude'])
      .size()
      .reset_index(name='Order_Count')
)

fig = px.scatter_map(
    delivery_areas,
    lat='Delivery_location_latitude',
    lon='Delivery_location_longitude',
    size='Order_Count',
    color='Order_Count',
    zoom=5,
    map_style='open-street-map',
    title='Delivery Locations by Order Volume'
)

fig.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The delivery locations are distributed across different regions of India, with higher order volumes concentrated mainly in Western and Southern regions. These areas have larger and brighter circles, indicating higher order counts, while smaller purple circles represent locations with relatively lower order volumes.
# <br>
#     <b> Insight :</b> The map indicates that delivery demand varies across geographic locations. Western and Southern regions show stronger order concentration in this dataset, while Northern and Eastern regions have comparatively lower order volumes. This suggests that location plays a role in the distribution of delivery demand.

# %% [markdown]
# <h3 style="
#     text-align: center ;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size:30px;
#     padding: 20px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Bivariate Analysis
# </h3>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     9) Is there a relationship between delivery partner age and delivery speed category?
# </h3>

# %%
mean_age_cat= df.groupby('delivery_speed')['Delivery_person_Age'].mean()
mean_age_cat
colors= ['red','green','orange']
plt.bar(mean_age_cat.index, mean_age_cat.values, color= colors)
plt.xlabel ('Delivery speed')
plt.ylabel('Delivery person age')
plt.title('Delivery person age v/s Delivery speed')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b>The <b>Slow delivery speed category</b>  has the highest average delivery partner age, while the <b>Fast category </b>has the lowest average age. Delivery partners in the <b>Average speed category</b>  fall between these two.
#     <br>
#     <b> Insight :</b>This suggests that younger delivery partners are more commonly associated with the Fast delivery speed category, whereas older delivery partners are more likely to fall under the Slow category. However, the difference in average age is relatively small, so other factors may also influence delivery speed.</br>
# </p>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     10) How do weather conditions affect delivery time?
# </h3>

# %%
sns.boxplot(x='Weather_conditions',y='Time_taken (min)', data=df, palette= 'rainbow',hue='Weather_conditions')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation : Foggy weather</b> has the highest average delivery time <b>(29.22 minutes)</b>, followed closely by <b>Cloudy weather (29.15 minutes)</b>.<b> Sunny weather</b> has the lowest average delivery time <b>(22.20 minutes). Windy, Stormy, and Sandstorms</b> result in similar delivery times of around <b>26 minutes</b>.
#     <br>
#     <b> Insight :</b> Adverse weather conditions generally increase delivery time, with fog causing the greatest delay, while sunny weather allows the fastest deliveries.</br>
# </p>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     11) How do delivery speed categories vary across different city types?
# </h3>

# %%
speed_city = pd.crosstab(df['City'], df['delivery_speed'])

sns.heatmap(speed_city, annot=True, fmt='d')
plt.xlabel('Delivery Speed')
plt.ylabel('City Type')
plt.title('Delivery Speed Across City Types')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation : Metropolitan</b> areas have the highest number of deliveries, with <b>Average</b> speed being the most common, followed by <b>Slow and Fast deliveries. Urban</b> areas have more <b>Fast and Average</b> deliveries and <b>fewer Slow deliveries. Semi-Urban</b> areas have very few deliveries, and all of them are classified as <b>Slow</b>.
# Overall, <b>Average delivery speed</b> is the most common across all city types.
# <br>
#     <b> Insight :</b> Urban areas show better delivery speed, with more Fast and Average deliveries, while Semi-Urban areas show slower deliveries.
#         Metropolitan areas have a higher number of Slow deliveries, which may be related to traffic congestion and high order volume.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     12) How does the order-to-pickup time influence the total delivery time?
# </h3>

# %%
sns.boxplot(
    x='Order_to_Pickup_Time',
    y='Time_taken (min)',
    data=df,
    palette='Reds',
    hue='Order_to_Pickup_Time' 
)

plt.xlabel('Order to Pickup Time (minutes)')
plt.ylabel('Total Delivery Time (minutes)')
plt.title('Order-to-Pickup Time vs Total Delivery Time')

plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation : </b> The total delivery time remains almost the same for orders with 5, 10, and 15 minutes of order-to-pickup time. The median delivery time is around 26 minutes for all three groups, and the overall spread of delivery times is very similar across each pickup-time category.
# <br>
#     <b> Insight :</b> This suggests that the order-to-pickup time has little to no effect on the total delivery time. Instead, factors such as traffic, delivery distance, and route conditions are likely to have a greater influence on how long a delivery takes.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     13) Is there a relationship between order period and delivery speed?
# </h3>

# %%
pd.crosstab(df['order_period'], df['delivery_speed']).plot(
    kind='barh', stacked=True
)

plt.xlabel('Number of Deliveries')
plt.ylabel('Order Period')
plt.title('Delivery Speed Distribution by Order Period')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation : Night</b> has the <b>highest </b>number of deliveries, with Average-speed deliveries being the most common, followed by Fast and Slow deliveries. <b>Evening</b> has the <b>second-highest</b> number of orders and also has more Average and Slow deliveries than Fast deliveries. <b>Morning</b> has fewer orders but a higher share of Fast deliveries and very few Slow deliveries. <b>Noon/Afternoon</b> has the lowest number of orders, with Average-speed deliveries being the most common.
# <br>
#     <b> Insight :</b> Urban areas show better delivery speed, with more Fast and Average deliveries, while Semi-Urban areas show slower deliveries.
#         Metropolitan areas have a higher number of Slow deliveries, which may be related to traffic congestion and high order volume.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     14) How do festival periods affect the time taken for delivery?
# </h3>

# %%
sns.barplot(
    data=df,
    x='Festival',
    y='Time_taken (min)',color ='red'
)

plt.xlabel('Festival')
plt.ylabel('Average Time_taken (min)')
plt.title('Average Time_taken (min) During Festival Periods')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The bar plot shows that the average time taken for delivery during festival period is approximately <b>50 minutes</b> and average time taken for delivery during non festival period is approximately <b>25 minutes</b>. Hence, festival periods show greater variability compared with non-festival periods.
# <br>
#     <b> Insight :</b> Festival periods do appear to have a significant impact on the average time taken for delivery, which remains around 50 minutes. However, the greater variability during festivals suggests that delivery time increases during high-demand periods. This indicates that the festival period have a stronger influence on delivery speed.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     15) How does delivery time differ across different vehicle types?
# </h3>

# %%
sns.boxplot(
    data=df,
    x='Type_of_vehicle',
    y='Time_taken (min)',
    palette='rainbow', hue= 'Type_of_vehicle'
)

plt.xlabel('Vehicle Type')
plt.ylabel('Delivery Time (min)')
plt.title('Delivery Time by Vehicle Type')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The box plot shows that <b>motorcycles</b> have the highest median delivery time at around <b>27 minutes</b>, followed by <b>scooter</b> at around <b>25 minutes</b> and <b>electric scooters</b> at around <b>24 minutes</b>. Motorcycles also show a slightly wider spread in delivery times, while scooters and electric scooters have relatively similar distributions.
# <br>
#     <b> Insight :</b> Delivery time varies across vehicle types, with electric scooters showing the lowest median delivery time and motorcycles the highest but the difference is relatively small. This suggests that vehicle type may not be strong factor influencing the delivery time. However, factors such as delivery distance, traffic density, and weather conditions may also contribute to these differences.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     16) How do multiple deliveries influence delivery speed categories?
# </h3>

# %%
sns.countplot(
    data=df,
    x='multiple_deliveries',
    hue='delivery_speed'
)

plt.xlabel('Number of Multiple Deliveries')
plt.ylabel('Number of Orders')
plt.title('Delivery Speed Categories by Multiple Deliveries')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The chart shows that orders with <b>1 multiple delivery</b> have the highest overall volume and are mainly categorized as <b>Average speed</b>, with a considerable number of Fast deliveries. For <b>2 multiple deliveries, Slow deliveries</b> become dominant, while Fast deliveries are almost absent. Orders with <b>3 multiple deliveries</b> are exclusively categorized as <b>Slow.</b>
# <br>
#     <b> Insight :</b> Higher numbers of multiple deliveries are associated with slower delivery-speed categories. While orders with 0 or 1 multiple delivery have a substantial proportion of Fast and Average deliveries, orders with 2 or 3 multiple deliveries are predominantly Slow. This suggests that handling multiple deliveries at the same time may be associated with longer delivery times.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     17)Is there a relationship between delivery speed categories and customer ratings?
# </h3>

# %%
sns.violinplot(
    data=df,
    x='delivery_speed',
    y='Delivery_person_Ratings',
    hue='delivery_speed',
    palette='rainbow',
    legend=False
)

plt.xlabel('Delivery Speed')
plt.ylabel('Customer Rating')
plt.title('Customer Ratings Across Delivery Speed Categories')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The violin plot shows that <b>Fast</b> and <b>Average</b> delivery speed categories have higher customer ratings, with median ratings around <b>4.7</b> and most ratings concentrated between <b>4.6 and 4.9</b>. In contrast, <b>Slow</b> deliveries have a lower median rating of around <b>4.5</b> and a wider distribution, including more ratings below <b>4.3</b> and a few very low ratings near <b>2.4</b>.
#
# <br>
#     <b> Insight :</b> The violin plot shows that <b>Fast</b> and <b>Average</b> delivery speed categories have higher customer ratings, with median ratings around <b>4.7</b> and most ratings concentrated between <b>4.6 and 4.9</b>. In contrast, <b>Slow</b> deliveries have a lower median rating of around <b>4.5</b> and a wider distribution, including more ratings below <b>4.3</b> and a few very low ratings near <b>2.4</b>.
# </p>

# %% [markdown]
# <h3 style="
#     text-align: center ;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size:30px;
#     padding: 20px;
#     text-decoration: underline;
#     text-decoration-thickness: 3px;">
#     Multivariate Analysis
# </h3>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     18) How do traffic density and weather conditions together influence delivery time?
# </h3>

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x='Road_traffic_density',
    y='Time_taken (min)',
    hue='Weather_conditions',
    data=df,
    palette='Set2'
)

plt.xlabel('Road Traffic Density')
plt.ylabel('Average Delivery Time (min)')
plt.title('Average Delivery Time by Traffic Density and Weather Conditions')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> Under <b>Jam traffic, Fog and Cloudy</b> conditions yield the highest delivery times <b>(~37 minutes). Sunny weather</b> yields the lowest average delivery time across all traffic categories, maxing out at only<b> ~23.5 minutes</b> even during severe Jams. Stormy, Sandstorms, and Windy</b> conditions cluster around <b>30 minutes</b>. .
#     <br>
#     <b> Insight :</b> Heavy traffic causes much longer delays, especially when the weather is foggy or cloudy. Sunny weather has less effect on delivery time.Traffic density has a bigger effect on delivery time than most weather conditions. Medium or high traffic can add around 5–7 minutes to delivery time.</br>
# </p>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     19) How do traffic conditions and festival periods impact delivery time?
# </h3>

# %%
sns.barplot(x= 'Road_traffic_density',
            y='Time_taken (min)',
            hue='Festival',
            data=df,
            palette='Set2'
            )

plt.xlabel('Road Traffic Density')
plt.ylabel('Average Delivery Time (min)')
plt.title('Average Delivery Time by Traffic Density and Festival ')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> Festival days have much longer delivery times, around <b>42–46 minutes</b>, compared to <b>21–31 minutes </b>on non-festival days.On non-festival days, delivery time increases with traffic density, while even low traffic during festivals results in high delivery times. The highest delivery time is observed during festival days with jam traffic, at around <b>46 minutes</b>.
#
# <br>
#     <b> Insight :</b> Festivals have a greater impact on delivery time than traffic density. The longer delivery times during festivals, even when traffic is low, may be due to increased order volume, longer food preparation time, or higher workload for delivery partners.<br>
#     </p>

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     20) How do order type and city type together influence delivery time?
# </h3>

# %%
sns.barplot(
    data=df,
    x='City',
    y='Time_taken (min)',
    hue='Type_of_order',
    palette='rainbow'
)

plt.xlabel('City Type')
plt.ylabel('Average Delivery Time (min)')
plt.title('Average Delivery Time by Order Type and City Type')
plt.legend(title='Order Type')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b> The grouped bar chart compares average delivery time across Metropolitan, Urban, and Semi-Urban city types for four order types: Snack, Meal, Drinks, and Buffet.<b>Metropolitan</b> : Average delivery time is approximately <b>27.5 minutes</b> across all four order types.
# <b>Urban</b>: Records the lowest average delivery time, at approximately <b>23 minutes</b> across the order categories.
# <b>Semi-Urban</b>: Has substantially higher average delivery times, ranging from approximately <b>49.5 to 50.2 minutes</b> across the order types.
# <b>Order Type</b>: Within each city type, the differences in average delivery time between Snack, Meal, Drinks, and Buffet orders are very small.
# <br>
#     <b> Insight :</b> The results suggest that city type has a stronger association with delivery time than order type in this dataset. Delivery times remain relatively similar across different order types within each city, while substantial differences are observed between city types. Semi-Urban areas have considerably longer delivery times compared with Urban and Metropolitan areas. This suggests that factors associated with the delivery location and logistics may be more important in explaining delivery-time differences than the type of order.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     21)Within each city type, how does the combination of weather and traffic affect average delivery time?
# </h3>

# %%
pivot = pd.pivot_table(
    df,
    values='Time_taken (min)',
    index=['City', 'Weather_conditions'],
    columns='Road_traffic_density',
    aggfunc='mean'
).round()

pivot
# Out:
# Road_traffic_density              High   Jam   Low  Medium
# City          Weather_conditions
# Metropolitian Cloudy              29.0  37.0  23.0    30.0
#               Fog                 29.0  37.0  23.0    30.0
#               Sandstorms          29.0  31.0  21.0    28.0
#               Stormy              29.0  31.0  21.0    28.0
#               Sunny               25.0  24.0  23.0    21.0
#               Windy               28.0  31.0  22.0    28.0
# Semi-Urban    Cloudy               NaN  49.0   NaN    46.0
#               Fog                  NaN  50.0   NaN    45.0
#               Sandstorms          48.0  51.0   NaN    48.0
#               Stormy              49.0  50.0   NaN    48.0
#               Sunny               52.0  49.0   NaN     NaN
#               Windy               49.0  51.0   NaN    49.0
# Urban         Cloudy              28.0  36.0  20.0    25.0
#               Fog                 27.0  35.0  20.0    24.0
# ...

# %%
for city in pivot.index.get_level_values('City').unique():
    
    city_data = pivot.loc[city]
    
    plt.figure(figsize=(10, 6))
    
    sns.heatmap(
        city_data,
        annot=True,
        fmt='.1f',
        cmap='YlOrRd'
    )
    
    plt.title(f'Average Delivery Time by Weather and Traffic - {city}')
    plt.xlabel('Road Traffic Density')
    plt.ylabel('Weather Conditions')
    plt.show()

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b>The analysis shows that <b>Semi-Urban</b> areas have the <b>highest</b> average delivery time, while <b>Urban</b> areas generally have the <b>lowest.</b> Traffic also affects delivery time, with Jam traffic taking longer compared to Low traffic. Weather conditions also have an effect, as Sunny weather generally has lower delivery times, while Cloudy, Foggy, Sandstorm, and Stormy conditions tend to take longer. Overall, delivery time varies depending on the combination of city type, traffic density, and weather conditions. Some combinations in Semi-Urban areas have missing values, so those results should be interpreted carefully.
# <br>
#     <b> Insight :</b> The results suggest that traffic, weather, and city type together influence delivery time. Delivery operations may need more attention in Semi-Urban areas and during heavy traffic or unfavorable weather conditions to reduce delays.

# %% [markdown]
# <h3 style="
#     text-align: left;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 22px;
#     font-weight: bold;
#     padding: 10px 0;
# ">
#     22)Which numerical factors are most strongly correlated with delivery performance?
# </h3>

# %%
numeric_df = df.select_dtypes(include=['number'])
corr_matrix = numeric_df.corr()
corr_matrix
# Out:
#                              Delivery_person_Age  Delivery_person_Ratings  \
# Delivery_person_Age                     1.000000                -0.115576
# Delivery_person_Ratings                -0.115576                 1.000000
# Restaurant_latitude                     0.003967                -0.004139
# Restaurant_longitude                    0.010695                 0.003589
# Delivery_location_latitude              0.003951                -0.004857
# Delivery_location_longitude             0.010671                 0.002467
# Vehicle_condition                      -0.001259                 0.043358
# multiple_deliveries                     0.113789                -0.122455
# Time_taken (min)                        0.292634                -0.356608
# distance_km                            -0.002390                -0.106749
# Order_to_Pickup_Time                   -0.009549                 0.005848
# order_hour                              0.002529                -0.067094
#
# ...

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;">
#
# <p style="
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 20px;
#     color: black;
#     text-align: justify;
#     line-height: 1.6;
#     margin: 0;">
#     <b> Observation :</b>The <b>strongest positive correlation</b> is between <b>order hour and delivery distance (r=0.63)</b>, followed by <b>multiple deliveries and delivery time (r=0.38)</b>, and <b>distance and delivery time (r=0.32).</b> There is also a <b>moderate negative correlation</b> between <b>delivery person ratings and delivery time (r=−0.36)</b>, while <b>order-to-pickup time</b> shows almost <b>no correlation</b> with delivery time.
# <br>
#     <b> Insight :</b> These results suggest that longer distances and handling multiple deliveries tend to increase delivery time, whereas higher-rated delivery partners generally complete deliveries faster. The pickup time has little effect on the overall delivery time, indicating that travel-related factors have a greater influence on delivery performance.

# %% [markdown]
# <div style="
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     align-items: center;
#     background: linear-gradient(to right, #E23744, #C81D30);
#     min-height: 120px;
#     border-radius: 8px;
#     text-align: center;
#     padding: 15px 25px;">
#
# <h2 style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-weight: bold;
#         font-size: 30px;
#         margin: 0 0 8px 0;">
#         Phase 4
#     </h2>
#
# <p style="
#         color: white;
#         font-family: 'Times New Roman', Times, serif;
#         font-size: 22px;
#         text-align: center;
#         max-width: 1000px;
#         margin: 0;">
#         Summary and Conclusion: Key findings, overall conclusion and recommendations.
#     </p>
#
# </div>

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#    Summary
# </h2>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 18px 22px;
#     border-radius: 8px;
#     margin: 10px 0;
#     font-family: 'Times New Roman', Times, serif;
#     color: black;">
#
# <table style="
#     width: 100%;
#     border-collapse: collapse;
#     background-color: #FFF1F2;
#     font-family: 'Times New Roman', Times, serif;
#     font-size: 15px;
#     color: black;">
#
# <thead>
#         <tr style="background-color:#f2f2f2;">
#             <th style="border:1px solid #ddd; padding:12px; text-align:left;">
#                 Area
#             </th>
#             <th style="border:1px solid #ddd; padding:12px; text-align:left;">
#                 Key Finding
#             </th>
#             <th style="border:1px solid #ddd; padding:12px; text-align:left;">
#                 What it Means
#             </th>
#         </tr>
#     </thead>
#
# <tbody>
#
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 ⭐ Customer satisfaction
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Average delivery rating = <strong>4.6</strong>
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Overall satisfaction is high
#             </td>
#         </tr>
#
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 ⏱️ Pickup efficiency
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Average pickup time = <strong>10 min</strong>
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Pickup process is relatively efficient
#             </td>
#         </tr>
#
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 🌙 Peak demand
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Night has the highest orders
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 More resources may be needed during evening/night
#             </td>
#         </tr>
#
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 🌧️ Weather
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Foggy/cloudy weather increases delivery time
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Weather affects delivery efficiency
#             </td>
#         </tr>
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 🚦 Traffic
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Heavy traffic increases delivery time
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Traffic is an important operational challenge
#             </td>
#         </tr>
#
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 📍 City type
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Semi-Urban areas have much longer delivery times
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Location/logistics strongly affect performance
#             </td>
#         </tr>
#
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 📦 Multiple deliveries
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 More multiple deliveries → slower speeds
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Delivery workload affects performance
#             </td>
#         </tr>
#
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 🛵 Distance
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Distance is positively related to delivery time
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Longer routes take more time
#             </td>
#         </tr>
#
# <tr>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 🔄 Pickup vs delivery
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Very weak relationship
#             </td>
#             <td style="border:1px solid #ddd; padding:12px;">
#                 Pickup time is not a major determinant of total delivery time
#             </td>
#         </tr>
#
# </tbody>
# </table>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 20px 25px;
#     border-radius: 8px;
#     margin: 15px 0;
#     font-family: 'Times New Roman', Times, serif;
#     color: black;
# ">
#
# <h2 style="
#         font-size: 24px;
#         margin: 0 0 18px 0;
#         color: #E23744;
#     ">
#         What drives delivery time?
#     </h2>
# <h3 style="
#         font-size: 20px;
#         margin: 15px 0 8px 0;
#     ">
#         Factors that increase delivery time
#     </h3>
#
# <ul style="
#         font-size: 18px;
#         line-height: 1.7;
#         margin-top: 5px;
#         padding-left: 30px;
#     ">
#         <li>🚦 Heavy traffic</li>
#         <li>🌧️ Unfavourable weather</li>
#         <li>🎉 Festival periods</li>
#         <li>📏 Longer delivery distances</li>
#         <li>📦 Multiple deliveries</li>
#         <li>📍 Semi-Urban locations</li>
#     </ul>
#
#
# <h3 style="
#         font-size: 20px;
#         margin: 18px 0 8px 0;
#     ">
#         Factors associated with better delivery performance
#     </h3>
# <ul style="
#         font-size: 18px;
#         line-height: 1.7;
#         margin-top: 5px;
#         padding-left: 30px;
#     ">
#         <li>☀️ Sunny weather</li>
#         <li>🏙️ Urban locations</li>
#         <li>🛵 Fewer multiple deliveries</li>
#         <li>⭐ Higher-rated delivery partners</li>
#         <li>⭐ Non - Festival Period</li>
#     </ul>
#
#
# <h3 style="
#         font-size: 20px;
#         margin: 18px 0 8px 0;
#     ">
#         Factors with limited influence
#     </h3>
#
# <ul style="
#         font-size: 18px;
#         line-height: 1.7;
#         margin-top: 5px;
#         padding-left: 30px;
#     ">
#         <li>⏱️ Order-to-pickup time</li>
#         <li>🍱 Order type</li>
#     </ul>
#
# </div>

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#    Conclusion
# </h2>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 20px 25px;
#     border-radius: 8px;
#     margin: 15px 0;
#     font-family: 'Times New Roman', Times, serif;
#     color: black;
# ">
#
#
#
# <p style="
#         font-size: 18px;
#         line-height: 1.7;
#         text-align: justify;
#         margin: 0;
#     ">
#         The analysis concludes that <strong>Zomato delivery performance is influenced
#         by a combination of operational, geographical, environmental, and
#         workload-related factors</strong> rather than by a single variable.
#     </p>
#
# <p style="
#         font-size: 18px;
#         line-height: 1.7;
#         text-align: justify;
#         margin: 12px 0 0 0;
#     ">
#         The major factors associated with longer delivery times include
#         <strong>heavy traffic, unfavourable weather conditions, festival periods,
#         longer delivery distances, multiple deliveries, and Semi-Urban locations</strong>.
#         In contrast, sunny weather, Urban locations, and fewer multiple deliveries
#         are associated with better delivery performance.
#     </p>
#
# <p style="
#         font-size: 18px;
#         line-height: 1.7;
#         text-align: justify;
#         margin: 12px 0 0 0;
#     ">
#         The high average delivery-partner rating of <strong>4.6</strong> indicates
#         generally high customer satisfaction, while the average order-to-pickup
#         time of approximately <strong>10 minutes</strong> suggests that the pickup
#         process is relatively efficient. However, the analysis shows that
#         order-to-pickup time has little relationship with total delivery time.
#     </p>
#
# <p style="
#         font-size: 18px;
#         line-height: 1.7;
#         text-align: justify;
#         margin: 12px 0 0 0;
#     ">
#         Overall, the findings suggest that <strong>travel-related and operational
#         factors have a greater influence on delivery time than the initial pickup
#         process</strong>. Therefore, improving delivery efficiency would require
#         greater focus on route and distance management, multiple-delivery
#         allocation, peak-period planning, and effective handling of traffic and
#         adverse weather conditions.
#     </p>
#
# <div style="
#         background-color: white;
#         border-radius: 6px;
#         padding: 14px 18px;
#         margin-top: 18px;
#         font-size: 18px;
#         line-height: 1.6;
#         text-align: justify;
#     ">
#         <strong>💡 Final Insight:</strong><br>
#         Delivery efficiency depends more on the conditions encountered during
#         the delivery journey—such as <strong>distance, traffic, weather, location,
#         festival period and workload</strong>—than on the time taken to initiate the delivery.
#     </div>
#
# </div>

# %% [markdown]
# <h2 style="
#     text-align: center;
#     color: red;
#     font-family: 'Times New Roman', Times, serif;
#     padding: 10px;
#     border: 3px solid red;
#     border-radius: 8px;">
#    Recommendations to overcome challenges
# </h2>

# %% [markdown]
# <div style="
#     background-color: #FFF1F2;
#     border-left: 6px solid #E23744;
#     padding: 20px 25px;
#     border-radius: 8px;
#     margin: 15px 0;
#     font-family: 'Times New Roman', Times, serif;
#     color: black;
# ">
#
# <table style="
#         width: 100%;
#         border-collapse: collapse;
#         font-size: 17px;
#         line-height: 1.5;
#     ">
#
#  <thead>
#             <tr style="background-color: #FCE4E7;">
#                 <th style="
#                     border: 1px solid #E6B8BE;
#                     padding: 12px;
#                     text-align: left;
#                     width: 30%;
#                 ">
#                     Challenge Identified
#                 </th>
#
# <th style="
#                     border: 1px solid #E6B8BE;
#                     padding: 12px;
#                     text-align: left;
#                     width: 70%;
#                 ">
#                     Recommended Action
#                 </th>
#             </tr>
#         </thead>
#
#  <tbody>
#
# <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     🚦 <strong>Heavy traffic</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Use dynamic route planning and traffic-aware delivery
#                     assignment to select less congested routes.
#                 </td>
#             </tr>
#
# <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     🌧️ <strong>Unfavourable weather</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Provide weather-based route adjustments and allow
#                     additional delivery time during fog, storms, and other
#                     adverse conditions.
#                 </td>
#             </tr>
#
# <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     🎉 <strong>Festival periods</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Increase delivery-partner availability and prepare for
#                     higher order volumes during festivals and it may increase the traffic. Restaurants could
#                     also be encouraged to improve food-preparation capacity
#                     during peak periods.
#                 </td>
#             </tr>
#
#  <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     📏 <strong>Longer delivery distances</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Prioritize nearby delivery partners and restaurants where
#                     possible, and use route optimization to reduce unnecessary
#                     travel.
#                 </td>
#             </tr>
#
# <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     📦 <strong>Multiple deliveries</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Limit the number of orders assigned together, particularly
#                     when distances or routes are significantly different.
#                     Prioritize efficient grouping of nearby orders.
#                 </td>
#             </tr>
#   <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     📍 <strong>Semi-Urban areas</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Increase delivery-partner availability and improve delivery
#                     allocation and route planning in Semi-Urban locations,
#                     where delivery times are substantially higher.
#                 </td>
#             </tr>
# <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     🌙 <strong>High evening/night demand</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Schedule more delivery partners during Evening and Night
#                     periods to match the higher order volume.
#                 </td>
#             </tr>
#
#  <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     ⭐ <strong>Delivery performance</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Monitor delivery-partner performance and provide training
#                     or support where consistently slower delivery performance
#                     is observed.
#                 </td>
#             </tr>
#   <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     🛵 <strong>Vehicle differences</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Consider vehicle suitability when assigning longer or more
#                     challenging routes, while also accounting for traffic,
#                     distance, and weather.
#                 </td>
#             </tr>
#
#   <tr>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     ⏱️ <strong>Pickup time has limited influence</strong>
#                 </td>
#                 <td style="border:1px solid #E6B8BE; padding:12px;">
#                     Since pickup time has little relationship with total
#                     delivery time, improvement efforts should focus more on
#                     <strong>travel-related factors</strong> rather than
#                     concentrating only on reducing pickup time.
#                 </td>
#             </tr>
#
#   </tbody>
#     </table>
#
# </div>
